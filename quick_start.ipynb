# %% [markdown]
# # 🚀 ComfyUI Quick Start
#
# Colab에서 ComfyUI를 가장 빠르게 시작하는 방법
#
# **실행 방법**: 런타임 → 모두 실행 (Ctrl+F9)
#
# ---

# %%
# GPU 확인
# !nvidia-smi
import torch
print(f"\nGPU: {torch.cuda.get_device_name(0) if torch.cuda.is_available() else 'None'}")
print(f"VRAM: {torch.cuda.get_device_properties(0).total_mem / 1024**3:.1f} GB" if torch.cuda.is_available() else "No GPU")

# %%
# Google Drive 연결 (선택)
from google.colab import drive
drive.mount('/content/drive')
OUTPUT_DIR = "/content/drive/MyDrive/ComfyUI_Output"
import os; os.makedirs(OUTPUT_DIR, exist_ok=True)
print(f"✅ Drive 연결: {OUTPUT_DIR}")

# %%
# ComfyUI 설치 (약 2분)
# !git clone https://github.com/comfyanonymous/ComfyUI.git /content/ComfyUI 2>/dev/null || echo 'Already installed'
# !pip install -r /content/ComfyUI/requirements.txt -q
# !git clone https://github.com/ltdrdata/ComfyUI-Manager.git /content/ComfyUI/custom_nodes/ComfyUI-Manager 2>/dev/null || echo 'Already installed'
# !pip install ultralytics controlnet-aux -q
print('✅ ComfyUI 설치 완료')

# %%
# 모델 다운로드 (약 5분)
# !wget -q -c https://huggingface.co/stabilityai/stable-diffusion-xl-base-1.0/resolve/main/sd_xl_base_1.0.safetensors -P /content/ComfyUI/models/checkpoints/
# !wget -q -c https://huggingface.co/thibaud/controlnet-openpose-sdxl-1.0/resolve/main/OpenPoseXL2.safetensors -P /content/ComfyUI/models/controlnet/
# !wget -q -c https://huggingface.co/Bingsu/adetailer/resolve/main/face_yolov8m.pt -P /content/ComfyUI/models/ultralytics/bbox/
# !wget -q -c https://huggingface.co/Bingsu/adetailer/resolve/main/hand_yolov8s.pt -P /content/ComfyUI/models/ultralytics/bbox/
print('✅ 모델 다운로드 완료')

# %%
# ComfyUI 실행
import subprocess, threading, time
from IPython.display import HTML

def run():
    subprocess.run([
        'python', '/content/ComfyUI/main.py',
        '--listen', '0.0.0.0', '--port', '8188',
        '--lowvram', '--output-directory', OUTPUT_DIR
    ])

threading.Thread(target=run, daemon=True).start()
time.sleep(10)

url = eval_js('google.colab.kernel.proxyPort(8188)')
display(HTML(f'<h2>\n\n🔗 <a href="{url}" target="_blank">여기를 클릭하여 ComfyUI 열기</a>\n\n</h2>'))
